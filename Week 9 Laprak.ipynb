# %%
data_mahasiswa = {
  'Nama\t\t' : ': Galang Ahmad Ghifari',
  'Kelas\t\t' : ': 2',
  'Tanggal Lahir\t' : ': 6 Agustus 2005',
  'No Hp\t\t' : ': 085951698604',
  'Alamat\t\t' : ': Banjarnegara',
  'Hobi\t\t' : ':',
  '  1.': "Olahraga",
  '  2.': 'Mancing',
  '  3.': 'Musik',
}

for i,j in data_mahasiswa.items():
  print(i, j)
# Out:
# Nama		 : Galang Ahmad Ghifari
# Kelas		 : 2
# Tanggal Lahir	 : 6 Agustus 2005
# No Hp		 : 085951698604
# Alamat		 : Banjarnegara
# Hobi		 :
#   1. Olahraga
#   2. Mancing
#   3. Musik
